# %% [markdown]
# ## Task 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1, 5, 9, 7, 5, 3])

# %%
print("a mean : ", np.mean(a))
# Out:
# a mean :  5.0

# %%
print("a median : " , np.median(a))
# Out:
# a median :  5.0

# %%
print("a var : " , np.var(a))
# Out:
# a var :  6.666666666666667

# %%
print("a std : " , np.sqrt(a.var()))
print("a std : " , np.std(a))
# Out:
# a std :  2.581988897471611
# a std :  2.581988897471611

# %% [markdown]
# ## Task 2

# %%
Dice = np.array([1, 2, 3, 4, 5, 6])

# %%
value , count = np.unique(Dice, return_counts=True)
print("value : ", value)
print("count : ", count)
# Out:
# value :  [1 2 3 4 5 6]
# count :  [1 1 1 1 1 1]

# %%
pmf = count / count.sum()
print("pmf : ", pmf)
# Out:
# pmf :  [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]

# %%
plt.figure(figsize=(10, 5))
plt.bar(Dice, pmf , width=0.5, color='green', alpha=0.7)
plt.xlabel("Dice")
plt.ylabel("Probability")
plt.title("PMF of Dice")
plt.show()

# %%
prob = 1 / len(Dice)
probs = [prob] * len(Dice)
cdf = np.cumsum(probs)
print("cdf : ", cdf)
# Out:
# cdf :  [0.16666667 0.33333333 0.5        0.66666667 0.83333333 1.        ]

# %%
plt.figure(figsize=(10, 5))
plt.bar(Dice, cdf , width=0.5, color='orange', alpha=0.7)
plt.xlabel("Dice")
plt.ylabel("Cumulative Probability")
plt.title("CDF of Dice")
plt.show()

# %% [markdown]
# ## Task 3

# %%
mean = 175
std_dev = 6
num_samples = 10000

data = np.random.normal(loc=mean, scale=std_dev, size=num_samples)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, density=True, alpha=0.7, color='b')
plt.title('Normal Distribution Histogram')
plt.xlabel('Value')
plt.ylabel('freq')
plt.show()

# %% [markdown]
# ## Task 4

# %%
from scipy.stats import poisson
from collections import Counter

lambda_val = 3.4
num_years = 10000
dataset = poisson.rvs(mu=lambda_val, size=num_years)

# %%
frequency = Counter(dataset)
print(frequency)
sorted_frequency = dict(sorted(frequency.items()))
print(sorted_frequency)
# Out:
# Counter({3: 2195, 2: 1925, 4: 1842, 5: 1204, 1: 1179, 6: 739, 7: 364, 0: 339, 8: 130, 9: 57, 10: 21, 11: 5})
# {0: 339, 1: 1179, 2: 1925, 3: 2195, 4: 1842, 5: 1204, 6: 739, 7: 364, 8: 130, 9: 57, 10: 21, 11: 5}

# %%
x = list(sorted_frequency.keys())
y = list(sorted_frequency.values())

# %%
for storms, year_count in zip(x, y):
    print(f"{storms} storms: {year_count} years")
# Out:
# 0 storms: 339 years
# 1 storms: 1179 years
# 2 storms: 1925 years
# 3 storms: 2195 years
# 4 storms: 1842 years
# 5 storms: 1204 years
# 6 storms: 739 years
# 7 storms: 364 years
# 8 storms: 130 years
# 9 storms: 57 years
# 10 storms: 21 years
# 11 storms: 5 years

# %%
plt.bar(x, y, width=0.7, alpha = 0.7 , color='red', edgecolor='black')
plt.xlabel("Number of Dust Storms per Year")
plt.ylabel("Number of Years")
plt.title(f"Poisson Distribution of Dust Storms (λ={lambda_val}) over {num_years} years")
plt.show()
